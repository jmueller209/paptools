# %%
from paptools import *
import numpy as np
set_option("verbose", False)
set_option("debug_level", "trace")

debug_print("This is a debug message", level="debug")
x = Array(np.linspace(-10,10, 1001), 0.1, symbol="pi", allow_complex=False)
a = Array(np.linspace(-10,10, 1001), 0.1, symbol="a", allow_complex=False)
y = x * epsilon0

print(sp.latex(y._err_expr))
print(sp.latex(y._expr))
y
# Out:
# \sqrt{\Delta{\varepsilon_0 }^{2} \pi^{2} + \Delta{pi}^{2} \varepsilon_{0 }^{2}}
# \varepsilon_{0 } \pi
# $\displaystyle \begin{aligned}\text{Value:} &\quad \varepsilon_{0 } \pi \\\text{Error:} &\quad \sqrt{\Delta{\varepsilon_0 }^{2} \pi^{2} + \Delta{pi}^{2} \varepsilon_{0 }^{2}}\end{aligned}$

# %%
from matplotlib import pyplot as plt
#plot with error bars
plt.errorbar(x._value, y._value, yerr=None, xerr=None, fmt='o', ecolor='r', capthick=2)
plt.ylabel("sin(x)")
plt.title("Plot of sin(x) with error bars")
plt.grid()
plt.show()

# %%
pi*e_charge
# Out:
# $\displaystyle \begin{aligned}\text{Value:} &\quad e \pi \\\text{Error:} &\quad 0\end{aligned}$

# %%
x = hbar

x
# Out:
# $\displaystyle \begin{aligned}\text{Value:} &\quad \bar{\h}\end{aligned}$
