# %%
from paptools import Number
import sympy as sp

# A length of 5.0 meters with an uncertainty of 0.1 meters, the unit is "m" (meters), and the symbol used in equations is "L"
x = Number(5.0, 0.1, unit="m", symbol="L")
y = Number(3.0, 0.2, unit="m", symbol="W")

L = x * y / 2

print(L)
print(sp.latex(L.get_err_expr()))
print(L.get_err_expr())
# Out:
# 7.5 ± 0.5220153254455275  m**2
# \sqrt{\frac{L^{2} \Delta{W}^{2}}{4} + \frac{W^{2} \Delta{L}^{2}}{4}}
# sqrt(L**2*\Delta{W}**2/4 + W**2*\Delta{L}**2/4)
