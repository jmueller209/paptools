# %%
from paptools import *


x = Array([1.1234, 2.234, 3.354], [0.2, 0.3, 0.4], symbol="x", unit="kg * km / s**2")
y = Array([1.345, 4.346, 8.345], 0.1, symbol="y", unit="kg * km / s**2")

z = Number(2.512341234, 0.1, symbol="z")


result = (x + y).convert_unit_to("N").round().set_symbol("F")
print(result)  # N = kg * m / s**2
result
# Out:
# [ 2470.  6600. 11700.] ± [230 400 500]  N
# $\displaystyle \begin{aligned}\text{Value:} &\quad F \\\text{Error:} &\quad \Delta{F}\end{aligned}$
